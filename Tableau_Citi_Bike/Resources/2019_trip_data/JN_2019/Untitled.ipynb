# %%
import pandas as pd
from pandas import to_datetime
import numpy as np

df1 = pd.read_csv("May_19.csv")
df1.head()

df1.count()

df1.dropna(how='any', inplace=True)
df1.count()

df1[pd.isnull(df1).any(axis=1)]

df1.dropna()

df1.isnull().any()

df1.drop_duplicates()

df1.columns

df1['Age'] = 2019 - df1['birth year']
df1

# Convert trip duration column from seconds to minutes
df1["tripduration"] = [trip/60 for trip in df1["tripduration"]]

# Filter out trips over 24 hours long
df1 = df1.loc[df1["tripduration"] < 1440, :]

# Rename trip duration column
#df1a.rename(columns={"Trip Duration":"Trip Duration (min)"})

df1.head()

df1.rename(columns = {'tripduration':'Trip Duration',  'starttime':'Start Time', 
                       'stoptime':'Stop Time', 'gender':'Gender', "usertype":"User Type",
                      'bikeid':'Bike ID', 'birth year':'Birth Year', 'start station id':'Start Station ID',
                      'start station name':'Start Station Name' , 'start station latitude':'lat1',
                       'start station longitude':'lon1', 'end station id':'End Station ID', 
                      'end station name':'End Station Name', 'end station latitude':'lat2',
                      'end station longitude':'lon2'}, inplace = True)

df1['Gender'].replace([0,1,2],['unknown','male','female'],inplace=True)
df1.head()

df1

df1.drop(df1.loc[df1['Trip Duration']<5].index, inplace=True)
df1.head()



may_df = df1[(df1['Birth Year'] >= 1995) & (df1['Birth Year'] <= 2002)]
may_df.head()

def haversine_distance(lat1, lon1, lat2, lon2):
   r = 6371
   phi1 = np.radians(lat1)
   phi2 = np.radians(lat2)
   delta_phi = np.radians(lat2-lat1)
   delta_lambda = np.radians(lon2-lon1)
   a = np.sin(delta_phi / 2)**2 + np.cos(phi1) * np.cos(phi2) *   np.sin(delta_lambda / 2)**2
   res = r * (2 * np.arctan2(np.sqrt(a), np.sqrt(1-a)))
   return np.round(res, 2)

may_df['distance'] = haversine_distance(may_df['lon1'],may_df['lat1'],may_df['lon2'],may_df['lat2'])
may_df.head()

may_df.reset_index(drop=True, inplace=True)
may_df.head()

#may_df.to_csv("May_2019.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-a08c5994acac> in <module>
#       3 import numpy as np
#       4
# ----> 5 df1 = pd.read_csv("May_19.csv")
#       6 df1.head()
#       7
#
# ~/opt/anaconda3/envs/PythonData1/lib/python3.6/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# --> 686     return _read(filepath_or_buffer, kwds)
#     687
#     688
#
# ~/opt/anaconda3/envs/PythonData1/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     450
#     451     # Create the parser.
# --> 452     parser = TextFileReader(fp_or_buf, **kwds)
#     453
#     454     if chunksize or iterator:
#
# ~/opt/anaconda3/envs/PythonData1/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     934             self.options["has_index_names"] = kwds["has_index_names"]
#     935
# --> 936         self._make_engine(self.engine)
#     937
#     938     def close(self):
#
# ~/opt/anaconda3/envs/PythonData1/lib/python3.6/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1166     def _make_engine(self, engine="c"):
#    1167         if engine == "c":
# -> 1168             self._engine = CParserWrapper(self.f, **self.options)
#    1169         else:
#    1170             if engine == "python":
#
# ~/opt/anaconda3/envs/PythonData1/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1996         kwds["usecols"] = self.usecols
#    1997
# -> 1998         self._reader = parsers.TextReader(src, **kwds)
#    1999         self.unnamed_cols = self._reader.unnamed_cols
#    2000
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'May_19.csv'

# %%
import pandas as pd
from pandas import to_datetime
import numpy as np

df1 = pd.read_csv("June_19-citibike-tripdata.csv")
df1.head()

df1.count()

df1.dropna(how='any', inplace=True)
df1.count()

df1[pd.isnull(df1).any(axis=1)]

df1.dropna()

df1.drop_duplicates()

df1.columns

df1['Age'] = 2019 - df1['birth year']
df1

# Convert trip duration column from seconds to minutes
df1["tripduration"] = [trip/60 for trip in df1["tripduration"]]

# Filter out trips over 24 hours long
df1 = df1.loc[df1["tripduration"] < 1440, :]

df1.head()

df1.rename(columns = {'tripduration':'Trip Duration',  'starttime':'Start Time', 
                       'stoptime':'Stop Time', 'gender':'Gender', "usertype":"User Type",
                      'bikeid':'Bike ID', 'birth year':'Birth Year', 'start station id':'Start Station ID',
                      'start station name':'Start Station Name' , 'start station latitude':'lat1',
                       'start station longitude':'lon1', 'end station id':'End Station ID', 
                      'end station name':'End Station Name', 'end station latitude':'lat2',
                      'end station longitude':'lon2'}, inplace = True)

df1.head()

df1['Gender'].replace([0,1,2],['unknown','male','female'],inplace=True)
df1.head()

df1.drop(df1.loc[df1['Trip Duration']<5].index, inplace=True)
df1.head()

june_df = df1[(df1['Birth Year'] >= 1995) & (df1['Birth Year'] <= 2002)]
june_df.head()

def haversine_distance(lat1, lon1, lat2, lon2):
   r = 6371
   phi1 = np.radians(lat1)
   phi2 = np.radians(lat2)
   delta_phi = np.radians(lat2-lat1)
   delta_lambda = np.radians(lon2-lon1)
   a = np.sin(delta_phi / 2)**2 + np.cos(phi1) * np.cos(phi2) *   np.sin(delta_lambda / 2)**2
   res = r * (2 * np.arctan2(np.sqrt(a), np.sqrt(1-a)))
   return np.round(res, 2)

june_df['distance'] = haversine_distance(june_df['lon1'],june_df['lat1'],june_df['lon2'],june_df['lat2'])
june_df.head()

june_df.reset_index(drop=True, inplace=True)
june_df.head()

#june_df.to_csv("June_2019.csv")

# %%
import pandas as pd
from pandas import to_datetime
import numpy as np

df1 = pd.read_csv("July_19-citibike-tripdata.csv")
df1.head()

df1.count()

df1.dropna(how='any', inplace=True)
df1.count()

df1[pd.isnull(df1).any(axis=1)]

df1.dropna()

df1.isnull().any()

df1.drop_duplicates()

df1.columns

df1['Age'] = 2019 - df1['birth year']
df1

# Convert trip duration column from seconds to minutes
df1["tripduration"] = [trip/60 for trip in df1["tripduration"]]

# Filter out trips over 24 hours long
df1 = df1.loc[df1["tripduration"] < 1440, :]

df1.head()

df1.rename(columns = {'tripduration':'Trip Duration',  'starttime':'Start Time', 
                       'stoptime':'Stop Time', 'gender':'Gender', "usertype":"User Type",
                      'bikeid':'Bike ID', 'birth year':'Birth Year', 'start station id':'Start Station ID',
                      'start station name':'Start Station Name' , 'start station latitude':'lat1',
                       'start station longitude':'lon1', 'end station id':'End Station ID', 
                      'end station name':'End Station Name', 'end station latitude':'lat2',
                      'end station longitude':'lon2'}, inplace = True)

df1['Gender'].replace([0,1,2],['unknown','male','female'],inplace=True)
df1.head()

df1.drop(df1.loc[df1['Trip Duration']<5].index, inplace=True)
df1.head()

july_df = df1[(df1['Birth Year'] >= 1995) & (df1['Birth Year'] <= 2002)]
july_df.head()

def haversine_distance(lat1, lon1, lat2, lon2):
   r = 6371
   phi1 = np.radians(lat1)
   phi2 = np.radians(lat2)
   delta_phi = np.radians(lat2-lat1)
   delta_lambda = np.radians(lon2-lon1)
   a = np.sin(delta_phi / 2)**2 + np.cos(phi1) * np.cos(phi2) *   np.sin(delta_lambda / 2)**2
   res = r * (2 * np.arctan2(np.sqrt(a), np.sqrt(1-a)))
   return np.round(res, 2)

july_df['distance'] = haversine_distance(july_df['lon1'],july_df['lat1'],july_df['lon2'],july_df['lat2'])
july_df.head()

july_df.reset_index(drop=True, inplace=True)
july_df.head()

#july_df.to_csv("July_2019.csv")

# %%
import pandas as pd
from pandas import to_datetime
import numpy as np

df1 = pd.read_csv("August_19-citibike-tripdata.csv")
df1.head()

df1.count()

df1.dropna(how='any', inplace=True)
df1.count()

df1[pd.isnull(df1).any(axis=1)]

df1.dropna()

df1.isnull().any()

df1.drop_duplicates()

df1.columns

df1['Age'] = 2019 - df1['birth year']
df1

# Convert trip duration column from seconds to minutes
df1["tripduration"] = [trip/60 for trip in df1["tripduration"]]

# Filter out trips over 24 hours long
df1 = df1.loc[df1["tripduration"] < 1440, :]

df1.head()

df1.rename(columns = {'tripduration':'Trip Duration',  'starttime':'Start Time', 
                       'stoptime':'Stop Time', 'gender':'Gender', "usertype":"User Type",
                      'bikeid':'Bike ID', 'birth year':'Birth Year', 'start station id':'Start Station ID',
                      'start station name':'Start Station Name' , 'start station latitude':'lat1',
                       'start station longitude':'lon1', 'end station id':'End Station ID', 
                      'end station name':'End Station Name', 'end station latitude':'lat2',
                      'end station longitude':'lon2'}, inplace = True)

df1['Gender'].replace([0,1,2],['unknown','male','female'],inplace=True)
df1.head()

df1.drop(df1.loc[df1['Trip Duration']<5].index, inplace=True)
df1.head()

august_df = df1[(df1['Birth Year'] >= 1995) & (df1['Birth Year'] <= 2002)]
august_df.head()

def haversine_distance(lat1, lon1, lat2, lon2):
   r = 6371
   phi1 = np.radians(lat1)
   phi2 = np.radians(lat2)
   delta_phi = np.radians(lat2-lat1)
   delta_lambda = np.radians(lon2-lon1)
   a = np.sin(delta_phi / 2)**2 + np.cos(phi1) * np.cos(phi2) *   np.sin(delta_lambda / 2)**2
   res = r * (2 * np.arctan2(np.sqrt(a), np.sqrt(1-a)))
   return np.round(res, 2)

august_df['distance'] = haversine_distance(august_df['lon1'],august_df['lat1'],august_df['lon2'],august_df['lat2'])
august_df.head()

august_df.reset_index(drop=True, inplace=True)
august_df.head()

#august_df.to_csv("August_2019.csv")

# %%
df_all =  pd.concat([may_df, june_df, july_df, august_df], ignore_index=True)
df_all.tail()

# %%
df_all.tocsv("summer_2019.csv")
